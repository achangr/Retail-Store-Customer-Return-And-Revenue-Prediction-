# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Load the dataset
file_path = '/content/sample_data/Cleaned_Sheet1.xlsx'
data = pd.read_excel(file_path)

# Display the first few rows (optional for understanding)
print(data.head())
# Out:
#    Unnamed: 0 channelGrouping       date        fullVisitorId  \
# 0           0  Organic Search 2016-09-02  1131660440785959936
# 1           1  Organic Search 2016-09-02   377306020877927872
# 2           2  Organic Search 2016-09-02  3895546263509774848
# 3           3  Organic Search 2016-09-02  4763447161404445696
# 4           4  Organic Search 2016-09-02    27294437909732080
#
#     Returned Customers  NewReturning                       sessionId  \
# 0   318069005254603008           NaN  1131660440785968503_1472830385
# 1  4777835233446890496           NaN   377306020877927890_1472880147
# 2  7531555119274919936           NaN  3895546263509774583_1472865386
# 3  9638558661446707200           NaN  4763447161404445595_1472881213
# 4   633483263499318528           NaN    27294437909732085_1472822600
#
#    socialEngagementType     visitId  visitNumber  ...  totals_bounces  \
# 0  Not Socially Engaged  1472830385            1  ...               1
# 1  Not Socially Engaged  1472880147            1  ...               1
# 2  Not Socially Engaged  1472865386            1  ...               1
# 3  Not Socially Engaged  1472881213            1  ...               1
# 4  Not Socially Engaged  1472822600            2  ...               1
#
#   totals_newVisits trafficSource_campaign  trafficSource_source  \
# 0                1              (not set)                google
# 1                1              (not set)                google
# 2                1              (not set)                google
# 3                1              (not set)                google
# 4                0              (not set)                google
#
#   trafficSource_medium trafficSource_keyword trafficSource_isTrueDirect  \
# 0              organic        (not provided)                        NaN
# 1              organic        (not provided)                        NaN
# 2              organic        (not provided)                        NaN
# 3              organic       google + online                        NaN
# 4              organic        (not provided)                        1.0
#
#   trafficSource_referralPath isReturning pageviews_bin
# 0                    Unknown           0           Low
# 1                    Unknown           0           Low
# 2                    Unknown           0           Low
# 3                    Unknown           0           Low
# 4                    Unknown           0           Low
#
# [5 rows x 35 columns]

# %%
target_column = 'isReturning'
features = data.drop(columns=[target_column])  # All columns except the target
labels = data[target_column]

# %%
# Handle missing values (if any)
features = features.fillna(0)

# Encode categorical variables (if any)
features = pd.get_dummies(features, drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# %%
# Train a logistic regression model
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# <ipython-input-6-486682f8c713> in <cell line: 3>()
#       1 # Train a logistic regression model
#       2 model = LogisticRegression(max_iter=1000, random_state=42)
# ----> 3 model.fit(X_train, y_train)
#       4
#       5 # Make predictions
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
#    1224             X,
#    1225             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1299         )
#    1300
# -> 1301     X = check_array(
#    1302         X,
#    1303         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     885         )
#     886         if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 887             dtype_orig = np.result_type(*dtypes_orig)
#     888         elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     889             # Force object if any of the dtypes is an object
#
# DTypePromotionError: The DType <class 'numpy.dtypes.DateTime64DType'> could not be promoted by <class 'numpy.dtypes.Float64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.DateTime64DType'>, <class 'numpy.dtypes.UInt64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class...
